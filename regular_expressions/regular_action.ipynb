# %%
import re

# %%
# It finds a match: the substring starts with 'A' and ends with 'a'
print(re.search(r"A.*a", "Argentina"))
print(re.search(r"A.*a", "Azerbaijan"))
# r"^A.*a$" checks if a string starts with 'A' and ends with 'a' with any number of characters in between. 
print(re.search(r"^A.*a$", "Australia"))
# Out:
# <re.Match object; span=(0, 9), match='Argentina'>
# <re.Match object; span=(0, 9), match='Azerbaija'>
# <re.Match object; span=(0, 9), match='Australia'>

# %%
# Start with a letter (either uppercase or lowercase) or an underscore.
# Followed by zero or more letters, digits, or underscores.
# Must cover the entire string from start to end without any invalid characters.
pattern = r"^[a-zA-Z_][a-zA-Z0-9_]*$"
print(re.search(pattern, "_this_is_a_valid_variable_name"))
print(re.search(pattern, "this isn't a valid variable"))
print(re.search(pattern, "my_variable1"))
print(re.search(pattern, "2my_variable1"))
# Out:
# <re.Match object; span=(0, 30), match='_this_is_a_valid_variable_name'>
# None
# <re.Match object; span=(0, 12), match='my_variable1'>
# None

# %% [markdown]
# ## Regex examples
#
# r”\d{3}-\d{3}-\d{4}”  This line of code matches U.S. phone numbers in the format 111-222-3333.
#
#
# r”^-?\d*(\.\d+)?$”  This line of code matches any positive or negative number, with or without decimal places.
#
#
# r”^(.+)\/([^\/]+)\/” This line of code matches any path and filename.
