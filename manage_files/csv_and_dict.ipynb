# %%
import csv

users = [ {"name": "Sol Mansi", "username": "solm", "department": "IT infrastructure"}, 
 {"name": "Lio Nelson", "username": "lion", "department": "User Experience Research"}, 
  {"name": "Charlie Grey", "username": "greyc", "department": "Development"}]
keys = ["name", "username", "department"]
with open('by_department.csv', 'w') as by_department:
    writer = csv.DictWriter(by_department, fieldnames=keys)
    writer.writeheader()
    writer.writerows(users)

# %%
f = open("by_department.csv")
csv_f = csv.reader(f)
next(csv_f, None)
for row in csv_f:
    name, username, department = row
    print("Name: {}, Username: {}, Department: {}".format(name, username, department))
f.close()
# Out:
# Name: Sol Mansi, Username: solm, Department: IT infrastructure
# Name: Lio Nelson, Username: lion, Department: User Experience Research
# Name: Charlie Grey, Username: greyc, Department: Development

# %%
# reading specific headers
with open('by_department.csv') as software:
    reader = csv.DictReader(software)
    for row in reader:
      print(("{} has {} users").format(row["name"], row["username"]))
# Out:
# Sol Mansi has solm users
# Lio Nelson has lion users
# Charlie Grey has greyc users
